# %%
import numpy as np
import pandas as pd
import nltk
import re
import os
import codecs
from sklearn import feature_extraction
import mpld3

# %%
titles = open('title_list.txt').read().split('\n')
titles = titles[:100]

links = open('link_list_imdb.txt').read().split('\n')
links = links[:100]

synopses_wiki = open('synopses_list_wiki.txt').read().split('\n BREAKS HERE')
synopses_wiki = synopses_wiki[:100]

synopses_clean_wiki = []

for text in synopses_wiki:
    text = nltk.clean_html(text)
    #strips html formatting
    
    text = text.replace('\xef', '')
    text = text.replace('&#xa0;', '\xA0')
    text = text.decode('utf-8', 'ignore')
    #gets rid of non-break space html and converts to unicode
    synopses_clean_wiki.append(text)

synopses_wiki = synopses_clean_wiki
    
    
genres = open('genres_list.txt').read().split('\n')
genres = genres[:100]

print(str(len(titles)) + ' titles')
print(str(len(links)) + ' links')
print(str(len(synopses_wiki)) + ' synopses')
print(str(len(genres)) + ' genres')
# Out:
# 100 titles
# 100 links
# 100 synopses
# 100 genres

# %%
synopses_imdb = open('synopses_list_imdb.txt').read().split('\n BREAKS HERE')
synopses_imdb = synopses_imdb[:100]

synopses_clean_imdb = []

for text in synopses_imdb:
    text = nltk.clean_html(text)
    #strips html formatting
    
    text = text.replace('\xef', '')
    text = text.replace('&#xa0;', '\xA0')
    text = text.decode('utf-8', 'ignore')
    #gets rid of non-break space html and converts to unicode
    synopses_clean_imdb.append(text)

synopses_imdb = synopses_clean_imdb

# %%
synopses = []

for i in range(len(synopses_wiki)):
    item = synopses_wiki[i] + synopses_imdb[i]
    synopses.append(item)

# %%
print(len(synopses[0]))
# Out:
# 26782

# %%
# generates index for each item in the corpora (in this case it's just rank)

ranks = []

for i in range(0,len(titles)):
    ranks.append(i)

# %%
# load nltk's English stopwords as variable called 'stopwords'

stopwords = nltk.corpus.stopwords.words('english')

# %%
# load nltk's SnowballStemmer as variabled 'stemmer'

from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("english")

# %%
# here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed

def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in synopses:
    allwords_stemmed = tokenize_and_stem(i)
    totalvocab_stemmed.extend(allwords_stemmed)
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
print(len(totalvocab_stemmed))

print(len(totalvocab_tokenized))
# Out:
# 312209
# 312209

# %%
print totalvocab_stemmed[:10]
print totalvocab_tokenized[:10]
# Out:
# [u'plot', u'edit', u'edit', u'edit', u'on', u'the', u'day', u'of', u'his', u'onli']
# [u'plot', u'edit', u'edit', u'edit', u'on', u'the', u'day', u'of', u'his', u'only']

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)

# %%
str(vocab_frame.ix['wed'].values.tolist()[0][0])
# Out:
# 'wedding'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 min_df=0.2, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

# %time tfidf_matrix = tfidf_vectorizer.fit_transform(synopses)

print(tfidf_matrix.shape)
# Out:
# CPU times: user 28.7 s, sys: 863 ms, total: 29.5 s
# Wall time: 29.4 s
# (100, 563)

# %%
terms = tfidf_vectorizer.get_feature_names()

# %%
#from sklearn.pipeline import make_pipeline
#from sklearn.preprocessing import Normalizer
#from sklearn.decomposition import TruncatedSVD

#svd = TruncatedSVD(1000)
#lsa = make_pipeline(svd, Normalizer(copy=False))

#tfidf_matrix.LSA = lsa.fit_transform(tfidf_matrix)

# %%
from sklearn.metrics.pairwise import euclidean_distances
#dist = euclidean_distances(tfidf_matrix)

from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)

# %% [markdown]
# # #######
# blocking off some tests running CountVectorizer
# #######

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(tokenizer=tokenize_and_stem, stop_words=stopwords)

# %time dtm = vectorizer.fit_transform(synopses)  # a sparse matrix

vocab = vectorizer.get_feature_names()  # a list
# Out:
# CPU times: user 17 s, sys: 155 ms, total: 17.2 s
# Wall time: 19.7 s

# %%
type(dtm)

dtm = dtm.toarray()  # convert to a regular array

vocab = np.array(vocab)

# %%
from sklearn.metrics.pairwise import cosine_similarity

#dist = 1- cosine_similarity(dtm)

# %% [markdown]
# # #####################

# %% [markdown]
# # #######
# blocking off a KMEANS (or WARD) test using the Pattern module
# #######

# %%
from pattern.vector import Document, Model, KMEANS, distance, COSINE

synopses_docs = [Document(synopses[i], name=titles[i]) for i in range(len(synopses))]

m = Model(documents = synopses_docs)

movieclusters = m.cluster(method=KMEANS, k=5)

# %%
for i in movieclusters:
    print(i)
    print()
# Out:
# [Document(id='Oxcy1Sr-134', name='The Lord of the Rings: The Return of the King'), Document(id='Oxcy1Sr-123', name='The Silence of the Lambs'), Document(id='Oxcy1Sr-193', name='Taxi Driver'), Document(id='Oxcy1Sr-163', name='All Quiet on the Western Front'), Document(id='Oxcy1Sr-138', name='Unforgiven'), Document(id='Oxcy1Sr-183', name='Network'), Document(id='Oxcy1Sr-186', name='American Graffiti'), Document(id='Oxcy1Sr-156', name='Platoon'), Document(id='Oxcy1Sr-199', name='North by Northwest'), Document(id='Oxcy1Sr-110', name='Titanic'), Document(id='Oxcy1Sr-121', name='E.T. the Extra-Terrestrial'), Document(id='Oxcy1Sr-195', name='Double Indemnity'), Document(id='Oxcy1Sr-147', name='Ben-Hur'), Document(id='Oxcy1Sr-128', name='Some Like It Hot'), Document(id='Oxcy1Sr-109', name='The Wizard of Oz'), Document(id='Oxcy1Sr-143', name='To Kill a Mockingbird'), Document(id='Oxcy1Sr-165', name='City Lights'), Document(id='Oxcy1Sr-119', name='West Side Story'), Document(id='Oxcy1Sr-144', name='An American in Paris'), Document(id='Oxcy1Sr-191', name='The Maltese Falcon')]
#
# [Document(id='Oxcy1Sr-159', name='The Pianist'), Document(id='Oxcy1Sr-130', name='Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb'), Document(id='Oxcy1Sr-118', name='The Sound of Music'), Document(id='Oxcy1Sr-124', name='Chinatown'), Document(id='Oxcy1Sr-137', name='Saving Private Ryan'), Document(id='Oxcy1Sr-152', name='The Good, the Bad and the Ugly'), Document(id='Oxcy1Sr-162', name='The Deer Hunter'), Document(id='Oxcy1Sr-155', name='The Apartment'), Document(id='Oxcy1Sr-151', name='Braveheart'), Document(id='Oxcy1Sr-103', name="Schindler's List"), Document(id='Oxcy1Sr-172', name='Annie Hall'), Document(id='Oxcy1Sr-178', name='Giant'), Document(id='Oxcy1Sr-111', name='Lawrence of Arabia'), Document(id='Oxcy1Sr-135', name='Gladiator'), Document(id='Oxcy1Sr-170', name='Mr. Smith Goes to Washington'), Document(id='Oxcy1Sr-150', name='Jaws'), Document(id='Oxcy1Sr-145', name='The Best Years of Our Lives'), Document(id='Oxcy1Sr-168', name='A Place in the Sun'), Document(id='Oxcy1Sr-104', name='Raging Bull'), Document(id='Oxcy1Sr-101', name='The Godfather')]
#
# [Document(id='Oxcy1Sr-149', name='Patton'), Document(id='Oxcy1Sr-188', name='The African Queen'), Document(id='Oxcy1Sr-197', name='Rear Window'), Document(id='Oxcy1Sr-127', name="It's a Wonderful Life"), Document(id='Oxcy1Sr-140', name='Rocky'), Document(id='Oxcy1Sr-112', name='The Godfather: Part II'), Document(id='Oxcy1Sr-198', name='The Third Man'), Document(id='Oxcy1Sr-169', name='Midnight Cowboy'), Document(id='Oxcy1Sr-176', name='Tootsie'), Document(id='Oxcy1Sr-160', name='Goodfellas'), Document(id='Oxcy1Sr-189', name='Stagecoach'), Document(id='Oxcy1Sr-171', name='Rain Man'), Document(id='Oxcy1Sr-153', name='Butch Cassidy and the Sundance Kid'), Document(id='Oxcy1Sr-182', name='Close Encounters of the Third Kind'), Document(id='Oxcy1Sr-174', name='Good Will Hunting'), Document(id='Oxcy1Sr-194', name='Wuthering Heights'), Document(id='Oxcy1Sr-106', name="One Flew Over the Cuckoo's Nest"), Document(id='Oxcy1Sr-185', name='The Graduate'), Document(id='Oxcy1Sr-157', name='High Noon'), Document(id='Oxcy1Sr-142', name='The Philadelphia Story')]
#
# [Document(id='Oxcy1Sr-173', name='Out of Africa'), Document(id='Oxcy1Sr-126', name="Singin' in the Rain"), Document(id='Oxcy1Sr-114', name='Sunset Blvd.'), Document(id='Oxcy1Sr-148', name='Doctor Zhivago'), Document(id='Oxcy1Sr-158', name='Dances with Wolves'), Document(id='Oxcy1Sr-181', name='The Green Mile'), Document(id='Oxcy1Sr-146', name='My Fair Lady'), Document(id='Oxcy1Sr-120', name='Star Wars'), Document(id='Oxcy1Sr-154', name='The Treasure of the Sierra Madre'), Document(id='Oxcy1Sr-108', name='Citizen Kane'), Document(id='Oxcy1Sr-200', name='Yankee Doodle Dandy'), Document(id='Oxcy1Sr-179', name='The Grapes of Wrath'), Document(id='Oxcy1Sr-190', name='Mutiny on the Bounty'), Document(id='Oxcy1Sr-136', name='From Here to Eternity'), Document(id='Oxcy1Sr-164', name='The French Connection'), Document(id='Oxcy1Sr-129', name='12 Angry Men'), Document(id='Oxcy1Sr-141', name='A Streetcar Named Desire'), Document(id='Oxcy1Sr-166', name="The King's Speech"), Document(id='Oxcy1Sr-102', name='The Shawshank Redemption'), Document(id='Oxcy1Sr-161', name='The Exorcist')]
#
# [Document(id='Oxcy1Sr-116', name='On the Waterfront'), Document(id='Oxcy1Sr-115', name='Vertigo'), Document(id='Oxcy1Sr-131', name='Amadeus'), Document(id='Oxcy1Sr-125', name='The Bridge on the River Kwai'), Document(id='Oxcy1Sr-184', name='Nashville'), Document(id='Oxcy1Sr-177', name='Fargo'), Document(id='Oxcy1Sr-105', name='Casablanca'), Document(id='Oxcy1Sr-107', name='Gone with the Wind'), Document(id='Oxcy1Sr-187', name='Pulp Fiction'), Document(id='Oxcy1Sr-139', name='Raiders of the Lost Ark'), Document(id='Oxcy1Sr-196', name='Rebel Without a Cause'), Document(id='Oxcy1Sr-175', name='Terms of Endearment'), Document(id='Oxcy1Sr-167', name='It Happened One Night'), Document(id='Oxcy1Sr-122', name='2001: A Space Odyssey'), Document(id='Oxcy1Sr-113', name='Psycho'), Document(id='Oxcy1Sr-133', name='Gandhi'), Document(id='Oxcy1Sr-132', name='Apocalypse Now'), Document(id='Oxcy1Sr-192', name='A Clockwork Orange'), Document(id='Oxcy1Sr-180', name='Shane'), Document(id='Oxcy1Sr-117', name='Forrest Gump')]

# %% [markdown]
# # #

# %%
from sklearn.cluster import KMeans

num_clusters = 5

km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)

clusters = km.labels_.tolist()
# Out:
# CPU times: user 233 ms, sys: 3.93 ms, total: 237 ms
# Wall time: 390 ms

# %%
from sklearn.externals import joblib

joblib.dump(km,  'doc_cluster.pkl')
# Out:
# ['doc_cluster.pkl', 'doc_cluster.pkl_01.npy', 'doc_cluster.pkl_02.npy']

# %%
import pandas as pd

films = { 'title': titles, 'rank': ranks, 'synopsis': synopses, 'cluster': clusters, 'genre': genres }

frame = pd.DataFrame(films, index = [clusters] , columns = ['rank', 'title', 'cluster', 'genre'])

# %%
frame['cluster'].value_counts()
# Out:
# 4    26
# 0    25
# 2    21
# 1    16
# 3    12
# dtype: int64

# %%
grouped = frame['rank'].groupby(frame['cluster'])

grouped.mean()
# Out:
# cluster
# 0          47.200000
# 1          58.875000
# 2          49.380952
# 3          54.500000
# 4          43.730769
# dtype: float64

# %%
grouped.count()
# Out:
# cluster
# 0          25
# 1          16
# 2          21
# 3          12
# 4          26
# dtype: int64

# %%
frame.ix[4]
# Out:
#    rank                                              title  cluster  \
# 4     1                           The Shawshank Redemption        4
# 4    10                                 Lawrence of Arabia        4
# 4    17                                 The Sound of Music        4
# 4    19                                          Star Wars        4
# 4    21                              2001: A Space Odyssey        4
# 4    24                       The Bridge on the River Kwai        4
# 4    29  Dr. Strangelove or: How I Learned to Stop Worr...        4
# 4    31                                     Apocalypse Now        4
# 4    33      The Lord of the Rings: The Return of the King        4
# 4    34                                          Gladiator        4
# 4    35                              From Here to Eternity        4
# 4    36                                Saving Private Ryan        4
# 4    37                                         Unforgiven        4
# 4    38                            Raiders of the Lost Ark        4
# 4    48                                             Patton        4
# 4    49                                               Jaws        4
# 4    52                 Butch Cassidy and the Sundance Kid        4
# 4    53                   The Treasure of the Sierra Madre        4
# 4    55                                            Platoon        4
# 4    57                                 Dances with Wolves        4
# 4    61                                    The Deer Hunter        4
# 4    62                     All Quiet on the Western Front        4
# 4    79                                              Shane        4
# 4    80                                     The Green Mile        4
# 4    87                                  The African Queen        4
# 4    89                               Mutiny on the Bounty        4
#
#                                                genre
# 4                             [u' Crime', u' Drama']
# 4  [u' Adventure', u' Biography', u' Drama', u' H...
# 4  [u' Biography', u' Drama', u' Family', u' Musi...
# 4  [u' Action', u' Adventure', u' Fantasy', u' Sc...
# 4                          [u' Mystery', u' Sci-Fi']
# 4                [u' Adventure', u' Drama', u' War']
# 4                              [u' Comedy', u' War']
# 4                               [u' Drama', u' War']
# 4                       [u' Adventure', u' Fantasy']
# 4                            [u' Action', u' Drama']
# 4                  [u' Drama', u' Romance', u' War']
# 4                   [u' Action', u' Drama', u' War']
# 4                                      [u' Western']
# 4                        [u' Action', u' Adventure']
# 4                [u' Biography', u' Drama', u' War']
# 4                          [u' Drama', u' Thriller']
# 4            [u' Biography', u' Crime', u' Western']
# 4  [u' Action', u' Adventure', u' Drama', u' West...
# 4                               [u' Drama', u' War']
# 4            [u' Adventure', u' Drama', u' Western']
# 4                               [u' Drama', u' War']
# 4                               [u' Drama', u' War']
# 4              [u' Drama', u' Romance', u' Western']
# 4   [u' Crime', u' Drama', u' Fantasy', u' Mystery']
# 4              [u' Adventure', u' Romance', u' War']
# 4            [u' Adventure', u' Drama', u' History']

# %%
cluster_names = {0: 'Family, home, war', 1: 'Police, killed, murders', 2: 'Father, New York, brothers', 3: 'Dance, singing, love', 4: 'Killed, soldiers, captain'}

# %%
from __future__ import print_function

print("Top terms per cluster:")
print()
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    for ind in order_centroids[i, :6]:
        print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
    print()
    print()
    print("Cluster %d titles:" % i, end='')
    for title in frame.ix[i]['title'].values.tolist():
        print(' %s,' % title, end='')
    print()
    print()
# Out:
# Top terms per cluster:
#
# Cluster 0 words: family, home, mother
# , war, house
# , dies,
#
# Cluster 0 titles: Schindler's List, One Flew Over the Cuckoo's Nest, Gone with the Wind, The Wizard of Oz, Titanic, Forrest Gump, E.T. the Extra-Terrestrial, The Silence of the Lambs, Gandhi, A Streetcar Named Desire, The Best Years of Our Lives, My Fair Lady, Ben-Hur, Doctor Zhivago, The Pianist, The Exorcist, Out of Africa, Good Will Hunting, Terms of Endearment, Giant, The Grapes of Wrath, Close Encounters of the Third Kind, The Graduate, Stagecoach, Wuthering Heights,
#
# Cluster 1 words: police
# , car, killed
# , murders, driving
# , house,
#
# Cluster 1 titles: Casablanca, Psycho, Sunset Blvd., Vertigo, Chinatown, Amadeus, High Noon, The French Connection, Fargo, Pulp Fiction, The Maltese Falcon, A Clockwork Orange, Double Indemnity, Rebel Without a Cause, The Third Man, North by Northwest,
#
# Cluster 2 words: father
# , new, york
# , new, brothers
# , apartments,
#
# Cluster 2 titles: The Godfather, Raging Bull, Citizen Kane, The Godfather: Part II, On the Waterfront, 12 Angry Men, Rocky, To Kill a Mockingbird, Braveheart, The Good, the Bad and the Ugly, The Apartment, Goodfellas, City Lights, It Happened One Night, Midnight Cowboy, Mr. Smith Goes to Washington, Rain Man, Annie Hall, Network, Taxi Driver, Rear Window,
#
# Cluster 3 words: george
# , dance
# , singing
# , john, love
# , perform,
#
# Cluster 3 titles: West Side Story, Singin' in the Rain, It's a Wonderful Life, Some Like It Hot, The Philadelphia Story, An American in Paris, The King's Speech, A Place in the Sun, Tootsie, Nashville, American Graffiti, Yankee Doodle Dandy,
#
# Cluster 4 words: killed
# , soldiers
# , captain
# , men, army
# , command
# ,
#
# Cluster 4 titles: The Shawshank Redemption, Lawrence of Arabia, The Sound of Music, Star Wars, 2001: A Space Odyssey, The Bridge on the River Kwai, Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb, Apocalypse Now, The Lord of the Rings: The Return of the King, Gladiator, From Here to Eternity, Saving Private Ryan, Unforgiven, Raiders of the Lost Ark, Patton, Jaws, Butch Cassidy and the Sundance Kid, The Treasure of the Sierra Madre, Platoon, Dances with Wolves, The Deer Hunter, All Quiet on the Western Front, Shane, The Green Mile, The African Queen, Mutiny on the Bounty,

# %%
cluster_names
# Out:
# {0: 'Family, home, war',
#  1: 'Police, killed, murders',
#  2: 'Father, New York, brothers',
#  3: 'Dance, singing, love',
#  4: 'Killed, soldiers, captain'}

# %%
#This is purely to help export tables to html and to correct for my 0 start rank (so that Godfather is 1, not 0)
frame['Rank'] = frame['rank'] + 1
frame['Title'] = frame['title']

# %%
#export tables to HTML
print(frame[['Rank', 'Title']].loc[frame['cluster'] == 1].to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Rank</th>
#       <th>Title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>  5</td>
#       <td>            Casablanca</td>
#     </tr>
#     <tr>
#       <td> 13</td>
#       <td>                Psycho</td>
#     </tr>
#     <tr>
#       <td> 14</td>
#       <td>          Sunset Blvd.</td>
#     </tr>
#     <tr>
#       <td> 15</td>
#       <td>               Vertigo</td>
#     </tr>
#     <tr>
#       <td> 24</td>
#       <td>             Chinatown</td>
#     </tr>
#     <tr>
#       <td> 31</td>
#       <td>               Amadeus</td>
#     </tr>
#     <tr>
#       <td> 57</td>
#       <td>             High Noon</td>
#     </tr>
#     <tr>
#       <td> 64</td>
#       <td> The French Connection</td>
#     </tr>
#     <tr>
#       <td> 77</td>
#       <td>                 Fargo</td>
#     </tr>
#     <tr>
#       <td> 87</td>
#       <td>          Pulp Fiction</td>
#     </tr>
#     <tr>
#       <td> 91</td>
#       <td>    The Maltese Falcon</td>
#     </tr>
#     <tr>
#       <td> 92</td>
#       <td>    A Clockwork Orange</td>
#     </tr>
#     <tr>
#       <td> 95</td>
#       <td>      Double Indemnity</td>
#     </tr>
#     <tr>
#       <td> 96</td>
#       <td> Rebel Without a Cause</td>
#     </tr>
#     <tr>
#       <td> 98</td>
#       <td>         The Third Man</td>
#     </tr>
#     <tr>
#       <td> 99</td>
#       <td>    North by Northwest</td>
#     </tr>
#   </tbody>
# </table>

# %%
order_centroids.shape
# Out:
# (10, 563)

# %%
import os  # for os.path.basename

import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.manifold import MDS

MDS()

# two components as we're plotting points in a two-dimensional plane
# "precomputed" because we provide a distance matrix
# we will also specify `random_state` so the plot is reproducible.
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)

pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

xs, ys = pos[:, 0], pos[:, 1]

# %%
cluster_colors = {0: '#1b9e77', 1: '#d95f02', 2: '#7570b3', 3: '#e7298a', 4: '#66a61e'}

# %%
df = pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=titles))

groups = df.groupby('label')


# Plot
fig, ax = plt.subplots(figsize=(17,9))
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling

for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, label=name, color=cluster_colors[name], mec='none')
    ax.set_aspect('auto')
ax.legend(numpoints=1)

for i in range(len(df)):
    ax.text(df.ix[i]['x'], df.ix[i]['y'], df.ix[i]['title'], size=8)    
    
    
#plt.tight_layout()
#plt.show()
plt.savefig( 'clusters_small.png', dpi=200)

# %%
plt.close()

# %%
class TopToolbar(mpld3.plugins.PluginBase):
    """Plugin for moving toolbar to top of figure"""

    JAVASCRIPT = """
    mpld3.register_plugin("toptoolbar", TopToolbar);
    TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
    TopToolbar.prototype.constructor = TopToolbar;
    function TopToolbar(fig, props){
        mpld3.Plugin.call(this, fig, props);
    };

    TopToolbar.prototype.draw = function(){
      // the toolbar svg doesn't exist
      // yet, so first draw it
      this.fig.toolbar.draw();

      // then change the y position to be
      // at the top of the figure
      this.fig.toolbar.toolbar.attr("x", 150);
      this.fig.toolbar.toolbar.attr("y", 400);

      // then remove the draw function,
      // so that it is not called again
      this.fig.toolbar.draw = function() {}
    }
    """
    def __init__(self):
        self.dict_ = {"type": "toptoolbar"}

# %%
df = pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=titles, link=links ))

groups = df.groupby('label')


css = """

div {
  font-family:Arial, Helvetica, sans-serif;
}


g.mpld3-xaxis, g.mpld3-yaxis {
display: none; }


"""


cluster_colors = {0: '#1b9e77', 1: '#d95f02', 2: '#7570b3', 3: '#e7298a', 4: '#66a61e'}



# Plot
fig, ax = plt.subplots(figsize=(14,6))
ax.margins(0.03) # Optional, just adds 5% padding to the autoscaling

for name, group in groups:
    points = ax.plot(group.x, group.y, marker='o', linestyle='', ms=18, label=name, mec='none', color=cluster_colors[name])
    ax.set_aspect('auto')
    labels = [i for i in group.title]
    
    tooltip = mpld3.plugins.PointHTMLTooltip(points[0], labels,
                                       voffset=10, hoffset=10, css=css)
    mpld3.plugins.connect(fig, tooltip, TopToolbar())    

    ax.axes.get_xaxis().set_ticks([])
    ax.axes.get_yaxis().set_ticks([])
    
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)

    
#ax.legend(numpoints=1, ncol=3, bbox_to_anchor=(1., 1))



#plt.axis('off')

mpld3.show()
html = mpld3.fig_to_html(fig)
print(html)
# Out:
# Note: if you're in the IPython notebook, mpld3.show() is not the best command
#       to use. Consider using mpld3.display(), or mpld3.enable_notebook().
#       See more information at http://mpld3.github.io/quickstart.html.
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [15/Dec/2014 21:48:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Dec/2014 21:48:17] "GET /d3.js HTTP/1.1" 200 -
# stopping Server...
#
#
# <style>
#
#
# div {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
#
#
#
# div {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
#
#
#
# div {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
#
#
#
# div {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
#
#
#
# div {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
#
#
# </style>
#
# <div id="fig_el290745801570086793125459"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#        mpld3.draw_figure("fig_el290745801570086793125459", {"axes": [{"xlim": [-0.70189582032870046, 0.71051473536226761], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [-0.70189582032870046, 0.71051473536226761], "ylim": [-0.70830339802964049, 0.69370701811001245], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "left", "nticks": 0, "tickvalues": []}], "lines": [], "markers": [{"edgecolor": "none", "facecolor": "#1B9E77", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.3639610306789285], [4.676218837063681, -8.051703224294176], [2.3868279, -9.0], [0.0, -9.0], [-2.3868279, -9.0], [-4.676218837063681, -8.051703224294176], [-6.3639610306789285, -6.3639610306789285], [-8.051703224294176, -4.676218837063681], [-9.0, -2.3868279], [-9.0, 0.0], [-9.0, 2.3868279], [-8.051703224294176, 4.676218837063681], [-6.3639610306789285, 6.3639610306789285], [-4.676218837063681, 8.051703224294176], [-2.3868279, 9.0], [0.0, 9.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el29074665479312pts"}, {"edgecolor": "none", "facecolor": "#D95F02", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.3639610306789285], [4.676218837063681, -8.051703224294176], [2.3868279, -9.0], [0.0, -9.0], [-2.3868279, -9.0], [-4.676218837063681, -8.051703224294176], [-6.3639610306789285, -6.3639610306789285], [-8.051703224294176, -4.676218837063681], [-9.0, -2.3868279], [-9.0, 0.0], [-9.0, 2.3868279], [-8.051703224294176, 4.676218837063681], [-6.3639610306789285, 6.3639610306789285], [-4.676218837063681, 8.051703224294176], [-2.3868279, 9.0], [0.0, 9.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data02", "id": "el29074709227536pts"}, {"edgecolor": "none", "facecolor": "#7570B3", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.3639610306789285], [4.676218837063681, -8.051703224294176], [2.3868279, -9.0], [0.0, -9.0], [-2.3868279, -9.0], [-4.676218837063681, -8.051703224294176], [-6.3639610306789285, -6.3639610306789285], [-8.051703224294176, -4.676218837063681], [-9.0, -2.3868279], [-9.0, 0.0], [-9.0, 2.3868279], [-8.051703224294176, 4.676218837063681], [-6.3639610306789285, 6.3639610306789285], [-4.676218837063681, 8.051703224294176], [-2.3868279, 9.0], [0.0, 9.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data03", "id": "el29074665483024pts"}, {"edgecolor": "none", "facecolor": "#E7298A", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.36396103 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#          mpld3.draw_figure("fig_el290745801570086793125459", {"axes": [{"xlim": [-0.70189582032870046, 0.71051473536226761], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [-0.70189582032870046, 0.71051473536226761], "ylim": [-0.70830339802964049, 0.69370701811001245], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "left", "nticks": 0, "tickvalues": []}], "lines": [], "markers": [{"edgecolor": "none", "facecolor": "#1B9E77", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.3639610306789285], [4.676218837063681, -8.051703224294176], [2.3868279, -9.0], [0.0, -9.0], [-2.3868279, -9.0], [-4.676218837063681, -8.051703224294176], [-6.3639610306789285, -6.3639610306789285], [-8.051703224294176, -4.676218837063681], [-9.0, -2.3868279], [-9.0, 0.0], [-9.0, 2.3868279], [-8.051703224294176, 4.676218837063681], [-6.3639610306789285, 6.3639610306789285], [-4.676218837063681, 8.051703224294176], [-2.3868279, 9.0], [0.0, 9.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el29074665479312pts"}, {"edgecolor": "none", "facecolor": "#D95F02", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.3639610306789285], [4.676218837063681, -8.051703224294176], [2.3868279, -9.0], [0.0, -9.0], [-2.3868279, -9.0], [-4.676218837063681, -8.051703224294176], [-6.3639610306789285, -6.3639610306789285], [-8.051703224294176, -4.676218837063681], [-9.0, -2.3868279], [-9.0, 0.0], [-9.0, 2.3868279], [-8.051703224294176, 4.676218837063681], [-6.3639610306789285, 6.3639610306789285], [-4.676218837063681, 8.051703224294176], [-2.3868279, 9.0], [0.0, 9.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data02", "id": "el29074709227536pts"}, {"edgecolor": "none", "facecolor": "#7570B3", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.3639610306789285], [4.676218837063681, -8.051703224294176], [2.3868279, -9.0], [0.0, -9.0], [-2.3868279, -9.0], [-4.676218837063681, -8.051703224294176], [-6.3639610306789285, -6.3639610306789285], [-8.051703224294176, -4.676218837063681], [-9.0, -2.3868279], [-9.0, 0.0], [-9.0, 2.3868279], [-8.051703224294176, 4.676218837063681], [-6.3639610306789285, 6.3639610306789285], [-4.676218837063681, 8.051703224294176], [-2.3868279, 9.0], [0.0, 9.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data03", "id": "el29074665483024pts"}, {"edgecolor": "none", "facecolor": "#E7298A", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.363961 ...
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 150);
#       this.fig.toolbar.toolbar.attr("y", 400);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#                  mpld3.draw_figure("fig_el290745801570086793125459", {"axes": [{"xlim": [-0.70189582032870046, 0.71051473536226761], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [], "zoomable": true, "images": [], "xdomain": [-0.70189582032870046, 0.71051473536226761], "ylim": [-0.70830339802964049, 0.69370701811001245], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "bottom", "nticks": 0, "tickvalues": []}, {"scale": "linear", "tickformat": "", "grid": {"gridOn": false}, "fontsize": null, "position": "left", "nticks": 0, "tickvalues": []}], "lines": [], "markers": [{"edgecolor": "none", "facecolor": "#1B9E77", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.3639610306789285], [4.676218837063681, -8.051703224294176], [2.3868279, -9.0], [0.0, -9.0], [-2.3868279, -9.0], [-4.676218837063681, -8.051703224294176], [-6.3639610306789285, -6.3639610306789285], [-8.051703224294176, -4.676218837063681], [-9.0, -2.3868279], [-9.0, 0.0], [-9.0, 2.3868279], [-8.051703224294176, 4.676218837063681], [-6.3639610306789285, 6.3639610306789285], [-4.676218837063681, 8.051703224294176], [-2.3868279, 9.0], [0.0, 9.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el29074665479312pts"}, {"edgecolor": "none", "facecolor": "#D95F02", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.3639610306789285], [4.676218837063681, -8.051703224294176], [2.3868279, -9.0], [0.0, -9.0], [-2.3868279, -9.0], [-4.676218837063681, -8.051703224294176], [-6.3639610306789285, -6.3639610306789285], [-8.051703224294176, -4.676218837063681], [-9.0, -2.3868279], [-9.0, 0.0], [-9.0, 2.3868279], [-8.051703224294176, 4.676218837063681], [-6.3639610306789285, 6.3639610306789285], [-4.676218837063681, 8.051703224294176], [-2.3868279, 9.0], [0.0, 9.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data02", "id": "el29074709227536pts"}, {"edgecolor": "none", "facecolor": "#7570B3", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, -6.3639610306789285], [4.676218837063681, -8.051703224294176], [2.3868279, -9.0], [0.0, -9.0], [-2.3868279, -9.0], [-4.676218837063681, -8.051703224294176], [-6.3639610306789285, -6.3639610306789285], [-8.051703224294176, -4.676218837063681], [-9.0, -2.3868279], [-9.0, 0.0], [-9.0, 2.3868279], [-8.051703224294176, 4.676218837063681], [-6.3639610306789285, 6.3639610306789285], [-4.676218837063681, 8.051703224294176], [-2.3868279, 9.0], [0.0, 9.0]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data03", "id": "el29074665483024pts"}, {"edgecolor": "none", "facecolor": "#E7298A", "edgewidth": 0.5, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 9.0], [2.3868279, 9.0], [4.676218837063681, 8.051703224294176], [6.3639610306789285, 6.3639610306789285], [8.051703224294176, 4.676218837063681], [9.0, 2.3868279], [9.0, 0.0], [9.0, -2.3868279], [8.051703224294176, -4.676218837063681], [6.3639610306789285, - ...
#             })
#          });
# }
# </script>
# 127.0.0.1 - - [15/Dec/2014 21:48:18] "GET /mpld3.js HTTP/1.1" 200 -

# %%
plt.close()

# %%
from scipy.cluster.hierarchy import ward, dendrogram

linkage_matrix = ward(pos)

dendrogram(linkage_matrix, orientation="right", labels=titles);

#plt.tight_layout()
plt.show()

# %%
#strip any proper names from a text...unfortunately right now this is yanking the first word from a sentence too.
import string
def strip_proppers(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent) if word.islower()]
    return "".join([" "+i if not i.startswith("'") and i not in stri.punctuation else i for i in tokens]).strip()

# %%
#Latent Dirichlet Allocation implementation with Gensim

from gensim import corpora, models, similarities 

#remove proper names
preprocess = [strip_proppers(doc) for doc in synopses]

# %time tokenized_text = [tokenize_and_stem(text) for text in preprocess]

# %time texts = [[word for word in text if word not in stopwords] for text in tokenized_text]
# Out:
# CPU times: user 15 s, sys: 205 ms, total: 15.2 s
# Wall time: 15.4 s
# CPU times: user 4.37 s, sys: 31.6 ms, total: 4.41 s
# Wall time: 4.53 s

# %%
#print(len([word for word in texts[0] if word not in stopwords]))
print(len(texts[0]))
# Out:
# 1839

# %%
dictionary = corpora.Dictionary(texts)

# %%
dictionary.filter_extremes(no_below=1, no_above=0.8)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
len(corpus)
# Out:
# 100

# %%
lda = models.LdaModel(corpus, num_topics=6, id2word=dictionary, update_every=1, chunksize=10000, passes=100)

# %%
print(lda[corpus[0]])
# Out:
# [(1, 0.067116181736777594), (3, 0.052013190738463298), (5, 0.87838071596637446)]

# %%
lda.print_topics(6, num_words=20)
# Out:
# [u"0.006*fight + 0.006*n't + 0.005*ask + 0.005*go + 0.004*play + 0.004*say + 0.004*friend + 0.004*home + 0.004*show + 0.004*becaus + 0.004*want + 0.004*end + 0.004*two + 0.004*becom + 0.004*goe + 0.003*town + 0.003*gun + 0.003*come + 0.003*run + 0.003*train",
#  u"0.006*shark + 0.005*boat + 0.005*home + 0.004*say + 0.004*water + 0.004*come + 0.003*kill + 0.003*run + 0.003*marri + 0.003*father + 0.003*love + 0.003*go + 0.003*life + 0.003*day + 0.003*film + 0.003*friend + 0.003*die + 0.003*away + 0.003*n't + 0.003*would",
#  u'0.010*soldier + 0.009*kill + 0.006*men + 0.006*order + 0.005*offic + 0.005*wound + 0.004*arriv + 0.004*day + 0.004*sing + 0.004*night + 0.004*war + 0.004*attack + 0.004*son + 0.004*go + 0.004*villag + 0.003*fight + 0.003*refus + 0.003*command + 0.003*death + 0.003*perform',
#  u'0.005*kill + 0.005*order + 0.005*help + 0.004*friend + 0.004*ask + 0.004*famili + 0.004*home + 0.004*escap + 0.004*two + 0.004*men + 0.004*arriv + 0.004*die + 0.004*meet + 0.004*prison + 0.003*work + 0.003*command + 0.003*destroy + 0.003*learn + 0.003*plan + 0.003*ship',
#  u"0.006*car + 0.005*kill + 0.005*meet + 0.004*n't + 0.004*ask + 0.004*famili + 0.004*polic + 0.004*go + 0.004*say + 0.004*arriv + 0.004*want + 0.004*two + 0.004*friend + 0.004*night + 0.004*run + 0.004*doe + 0.004*day + 0.003*apart + 0.003*next + 0.003*call",
#  u'0.005*film + 0.004*learn + 0.004*ask + 0.004*night + 0.004*father + 0.003*appear + 0.003*name + 0.003*call + 0.003*discov + 0.003*water + 0.003*attempt + 0.003*two + 0.003*away + 0.003*polic + 0.003*also + 0.003*work + 0.003*pod + 0.003*kill + 0.003*music + 0.003*go']

# %%
import math
from __future__ import division

article_id = randint(0, tdm.shape[0] - 1)
article_text = reuters.raw(reuters.fileids()[article_id])

sent_scores = []
for sentence in nltk.sent_tokenize(article_text):
    score = 0
    sent_tokens = tokenize_and_stem(sentence)
    for token in (t for t in sent_tokens if t in feature_names):
        score += tdm[article_id, feature_names.index(token)]
    sent_scores.append((score / len(sent_tokens), sentence))

summary_length = int(math.ceil(len(sent_scores) / 5))
sent_scores.sort(key=lambda sent: sent[0])

print '*** SUMMARY ***'
for summary_sentence in sent_scores[:summary_length]:
    print summary_sentence[1]

print '\n*** ORIGINAL ***'
print article_text
